# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.359558
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$ *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# (1513, 9)
# numerical: 0.008708 analytic: 0.008708, relative error: 9.966901e-07
# (1611, 4)
# numerical: -1.075623 analytic: -1.075623, relative error: 5.414706e-09
# (2124, 4)
# numerical: -1.458204 analytic: -1.458204, relative error: 4.789400e-09
# (2939, 8)
# numerical: 0.001246 analytic: 0.001245, relative error: 5.580518e-05
# (2190, 9)
# numerical: 2.538568 analytic: 2.538568, relative error: 3.683456e-09
# (1725, 6)
# numerical: 2.635211 analytic: 2.635211, relative error: 2.434325e-08
# (191, 9)
# numerical: -4.427207 analytic: -4.427207, relative error: 6.753943e-09
# (1677, 6)
# numerical: -1.343117 analytic: -1.343117, relative error: 1.010704e-08
# (1925, 0)
# numerical: -3.202363 analytic: -3.202363, relative error: 3.037416e-08
# (3029, 0)
# numerical: -2.716677 analytic: -2.716677, relative error: 3.827026e-08
# (1121, 7)
# numerical: 1.909093 analytic: 1.909093, relative error: 4.598217e-08
# (1586, 9)
# numerical: -0.726907 analytic: -0.726907, relative error: 4.417320e-08
# (1341, 1)
# numerical: -0.864545 analytic: -0.864545, relative error: 1.560140e-08
# (2408, 1)
# numerical: 0.612145 analytic: 0.612145, relative error: 1.034376e-07
# (171, 8)
# numerical: -2.195131 analytic: -2.195131, relative error: 3.947109e-09
# (1073, 2)
# numerical: 0.872415 analytic: 0.872415, relative error: 1.179434e-08
# (2267, 8)
# numerical: -2.708299 analytic: -2.708299, relative error: 2.283781e-08
# (2553, 4)
# numerical: -1.303350 analytic: -1.303350, relative error: 2.502070e-08
# (554, 8)
# numerical: -4.715176 analytic: -4.715176, relative error: 5.500819e-09
# (2443, 0)
# numerical: -1.293372 analytic: -1.293372, relative error: 3.802209e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.359558e+00 computed in 0.102209s
# vectorized loss: 2.359558e+00 computed in 0.006011s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7,2e-7,3e-7,4e-7, 5e-7]
regularization_strengths = [2.5e4,3e4,4e4, 5e4]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
for lr in learning_rates:
    for rs in regularization_strengths:
        train_softmax=Softmax()
        train_softmax.train(X_train, y_train, learning_rate=lr, reg=rs,num_iters=1000, verbose=True)
        train_pred=train_softmax.predict(X_train)
        val_pred=train_softmax.predict(X_val)
        train_accuracy=np.mean(train_pred==y_train)
        val_accuracy=np.mean(val_pred==y_val)
        if val_accuracy>best_val:
            best_val=val_accuracy
            best_softmax=train_softmax
            print("当前最佳准确率为：")
            print(best_val)
        results[(lr,rs)]=(train_accuracy,val_accuracy)
pass

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, rs in sorted(results):
    train_accuracy, val_accuracy = results[(lr, rs)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, rs, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1000: loss 388.000485
# iteration 100 / 1000: loss 234.234082
# iteration 200 / 1000: loss 142.458945
# iteration 300 / 1000: loss 86.897855
# iteration 400 / 1000: loss 53.359524
# iteration 500 / 1000: loss 33.068041
# iteration 600 / 1000: loss 20.873692
# iteration 700 / 1000: loss 13.360070
# iteration 800 / 1000: loss 8.906050
# iteration 900 / 1000: loss 6.211007
# 当前最佳准确率为：
# 0.348
# iteration 0 / 1000: loss 466.474445
# iteration 100 / 1000: loss 255.142748
# iteration 200 / 1000: loss 140.272256
# iteration 300 / 1000: loss 77.637948
# iteration 400 / 1000: loss 43.539324
# iteration 500 / 1000: loss 24.749107
# iteration 600 / 1000: loss 14.397046
# iteration 700 / 1000: loss 8.851053
# iteration 800 / 1000: loss 5.784195
# iteration 900 / 1000: loss 4.099536
# 当前最佳准确率为：
# 0.356
# iteration 0 / 1000: loss 624.729752
# iteration 100 / 1000: loss 280.104109
# iteration 200 / 1000: loss 126.384668
# iteration 300 / 1000: loss 57.722512
# iteration 400 / 1000: loss 26.984254
# iteration 500 / 1000: loss 13.192278
# iteration 600 / 1000: loss 7.022142
# iteration 700 / 1000: loss 4.350246
# iteration 800 / 1000: loss 3.053957
# iteration 900 / 1000: loss 2.487755
# iteration 0 / 1000: loss 777.421184
# iteration 100 / 1000: loss 285.248703
# iteration 200 / 1000: loss 105.676315
# iteration 300 / 1000: loss 39.987002
# iteration 400 / 1000: loss 15.911139
# iteration 500 / 1000: loss 7.114627
# iteration 600 / 1000: loss 3.983609
# iteration 700 / 1000: loss 2.720500
# iteration 800 / 1000: loss 2.389727
# iteration 900 / 1000: loss 2.124579
# iteration 0 / 1000: loss 388.308045
# iteration 100 / 1000: loss 142.436614
# iteration 200 / 1000: loss 53.392627
# iteration 300 / 1000: loss 20.837925
# iteration 400 / 1000: loss 8.900119
# iteration 500 / 1000: loss 4.580059
# iteration 600 / 1000: loss 2.942822
# iteration 700 / 1000: loss 2.355457
# iteration 800 / 1000: loss 2.126966
# iteration 900 / 1000: loss 2.072291
# iteration 0 / 1000: loss 463.702099
# iteration 100 / 1000: loss 139.483335
# iteration 200 / 1000: loss 43.055393
# iteration 300 / 1000: loss 14.286796
# iteration 400 / 1000: loss 5.726290
# iteration 500 / 1000: loss 3.115122
# iteration 600 / 1000: loss 2.366530
# iteration 700 / 1000: loss 2.152899
# iteration 800 / 1000: loss 2.050113
# iteration 900 / 1000: loss 2.060918
# 当前最佳准确率为：
# 0.357
# iteration 0 / 1000: loss 615.360404
# iteration 100 / 1000: loss 124.466637
# iteration 200 / 1000: loss 26.450311
# iteration 300 / 1000: loss 6.920112
# iteration 400 / 1000: loss 3.015637
# iteration 500 / 1000: loss 2.273008
# iteration 600 / 1000: loss 2.130814
# iteration 700 / 1000: loss 2.111386
# iteration 800 / 1000: loss 2.146211
# iteration 900 / 1000: loss 2.022847
# iteration 0 / 1000: loss 776.206069
# iteration 100 / 1000: loss 105.058896
# iteration 200 / 1000: loss 15.880534
# iteration 300 / 1000: loss 3.945651
# iteration 400 / 1000: loss 2.400635
# iteration 500 / 1000: loss 2.175038
# iteration 600 / 1000: loss 2.087750
# iteration 700 / 1000: loss 2.032406
# iteration 800 / 1000: loss 2.100156
# iteration 900 / 1000: loss 2.123626
# iteration 0 / 1000: loss 388.155829
# iteration 100 / 1000: loss 87.001429
# iteration 200 / 1000: loss 20.722785
# iteration 300 / 1000: loss 6.185211
# iteration 400 / 1000: loss 2.938039
# iteration 500 / 1000: loss 2.185684
# iteration 600 / 1000: loss 2.104407
# iteration 700 / 1000: loss 2.001749
# iteration 800 / 1000: loss 2.090019
# iteration 900 / 1000: loss 2.025316
# 当前最佳准确率为：
# 0.367
# iteration 0 / 1000: loss 465.002960
# iteration 100 / 1000: loss 77.322845
# iteration 200 / 1000: loss 14.265356
# iteration 300 / 1000: loss 4.079074
# iteration 400 / 1000: loss 2.360949
# iteration 500 / 1000: loss 2.121572
# iteration 600 / 1000: loss 1.968668
# iteration 700 / 1000: loss 2.070775
# iteration 800 / 1000: loss 1.956159
# iteration 900 / 1000: loss 2.070058
# iteration 0 / 1000: loss 620.301616
# iteration 100 / 1000: loss 56.634397
# iteration 200 / 1000: loss 6.904830
# iteration 300 / 1000: loss 2.447460
# iteration 400 / 1000: loss 2.118319
# iteration 500 / 1000: loss 2.070728
# iteration 600 / 1000: loss 2.016189
# iteration 700 / 1000: loss 2.097535
# iteration 800 / 1000: loss 2.039611
# iteration 900 / 1000: loss 2.043743
# iteration 0 / 1000: loss 779.160438
# iteration 100 / 1000: loss 39.486574
# iteration 200 / 1000: loss 3.864870
# iteration 300 / 1000: loss 2.184858
# iteration 400 / 1000: loss 2.123691
# iteration 500 / 1000: loss 2.083116
# iteration 600 / 1000: loss 2.098375
# iteration 700 / 1000: loss 2.099598
# iteration 800 / 1000: loss 2.092448
# iteration 900 / 1000: loss 2.092692
# iteration 0 / 1000: loss 393.812731
# iteration 100 / 1000: loss 53.732275
# iteration 200 / 1000: loss 8.851741
# iteration 300 / 1000: loss 3.008595
# iteration 400 / 1000: loss 2.167605
# iteration 500 / 1000: loss 2.009886
# iteration 600 / 1000: loss 2.027523
# iteration 700 / 1000: loss 2.063801
# iteration 800 / 1000: loss 1.988978
# iteration 900 / 1000: loss 1.997010
# iteration 0 / 1000: loss 469.215212
# iteration 100 / 1000: loss 43.383000
# iteration 200 / 1000: loss 5.710171
# iteration 300 / 1000: loss 2.390906
# iteration 400 / 1000: loss 2.002533
# iteration 500 / 1000: loss 2.075772
# iteration 600 / 1000: loss 1.976795
# iteration 700 / 1000: loss 2.057803
# iteration 800 / 1000: loss 2.001496
# iteration 900 / 1000: loss 2.012610
# iteration 0 / 1000: loss 621.488867
# iteration 100 / 1000: loss 26.423100
# iteration 200 / 1000: loss 2.988422
# iteration 300 / 1000: loss 2.112302
# iteration 400 / 1000: loss 2.067975
# iteration 500 / 1000: loss 2.020194
# iteration 600 / 1000: loss 2.028128
# iteration 700 / 1000: loss 2.056605
# iteration 800 / 1000: loss 2.067938
# iteration 900 / 1000: loss 2.112898
# iteration 0 / 1000: loss 773.216646
# iteration 100 / 1000: loss 15.530905
# iteration 200 / 1000: loss 2.338815
# iteration 300 / 1000: loss 2.089536
# iteration 400 / 1000: loss 2.120163
# iteration 500 / 1000: loss 2.057563
# iteration 600 / 1000: loss 2.073264
# iteration 700 / 1000: loss 2.075129
# iteration 800 / 1000: loss 2.065149
# iteration 900 / 1000: loss 2.122917
# iteration 0 / 1000: loss 389.355495
# iteration 100 / 1000: loss 32.816409
# iteration 200 / 1000: loss 4.482967
# iteration 300 / 1000: loss 2.227024
# iteration 400 / 1000: loss 2.034663
# iteration 500 / 1000: loss 2.117998
# iteration 600 / 1000: loss 2.009181
# iteration 700 / 1000: loss 2.081743
# iteration 800 / 1000: loss 1.969696
# iteration 900 / 1000: loss 1.979319
# iteration 0 / 1000: loss 466.447800
# iteration 100 / 1000: loss 24.284773
# iteration 200 / 1000: loss 3.129148
# iteration 300 / 1000: loss 2.182148
# iteration 400 / 1000: loss 2.002116
# iteration 500 / 1000: loss 2.048988
# iteration 600 / 1000: loss 2.069033
# iteration 700 / 1000: loss 2.061289
# iteration 800 / 1000: loss 2.091743
# iteration 900 / 1000: loss 2.031846
# iteration 0 / 1000: loss 614.953895
# iteration 100 / 1000: loss 12.673321
# iteration 200 / 1000: loss 2.224435
# iteration 300 / 1000: loss 2.051152
# iteration 400 / 1000: loss 2.104638
# iteration 500 / 1000: loss 2.072799
# iteration 600 / 1000: loss 2.041149
# iteration 700 / 1000: loss 2.016516
# iteration 800 / 1000: loss 2.111843
# iteration 900 / 1000: loss 2.054797
# iteration 0 / 1000: loss 775.703477
# iteration 100 / 1000: loss 6.944533
# iteration 200 / 1000: loss 2.089778
# iteration 300 / 1000: loss 2.149168
# iteration 400 / 1000: loss 2.115137
# iteration 500 / 1000: loss 2.057680
# iteration 600 / 1000: loss 2.104867
# iteration 700 / 1000: loss 2.096061
# iteration 800 / 1000: loss 2.076049
# iteration 900 / 1000: loss 2.037608
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.339000 val accuracy: 0.348000
# lr 1.000000e-07 reg 3.000000e+04 train accuracy: 0.337857 val accuracy: 0.356000
# lr 1.000000e-07 reg 4.000000e+04 train accuracy: 0.333714 val accuracy: 0.347000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.328286 val accuracy: 0.348000
# lr 2.000000e-07 reg 2.500000e+04 train accuracy: 0.348980 val accuracy: 0.352000
# lr 2.000000e-07 reg 3.000000e+04 train accuracy: 0.341571 val accuracy: 0.357000
# lr 2.000000e-07 reg 4.000000e+04 train accuracy: 0.337816 val accuracy: 0.357000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.321735 val accuracy: 0.335000
# lr 3.000000e-07 reg 2.500000e+04 train accuracy: 0.351959 val accuracy: 0.367000
# lr 3.000000e-07 reg 3.000000e+04 train accuracy: 0.333694 val accuracy: 0.343000
# lr 3.000000e-07 reg 4.000000e+04 train accuracy: 0.329306 val accuracy: 0.353000
# lr 3.000000e-07 reg 5.000000e+04 train accuracy: 0.334939 val accuracy: 0.350000
# lr 4.000000e-07 reg 2.500000e+04 train accuracy: 0.345612 val accuracy: 0.358000
# lr 4.000000e-07 reg 3.000000e+04 train accuracy: 0.339571 val accuracy: 0.358000
# lr 4.000000e-07 reg 4.000000e+04 train accuracy: 0.327102 val accuracy: 0.350000
# lr 4.000000e-07 reg 5.000000e+04 train accuracy: 0.326000 val accuracy: 0.341000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.344041 val accuracy: 0.360000
# lr 5.000000e-07 reg 3.000000e+04 train accuracy: 0.336857 val accuracy: 0.338000
# lr 5.000000e-07 reg 4.000000e+04 train accuracy: 0.329245 val accuracy: 0.332000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.322551 val accuracy: 0.338000
# best validation accuracy achieved during cross-validation: 0.367000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.357000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$
#
#
# $\color{blue}{\textit Your Explanation:}$

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
